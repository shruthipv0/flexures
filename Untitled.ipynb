# %%
from PIL import Image

image1 = Image.open("patterns/glasgow.png")
image1.show()

img = Image.open("patterns/glasgow.png")
img.show()

# %%
import matplotlib.pyplot as plt

#Load the image from file. then display it.
test_image = plt.imread("patterns/glasgow.png")
plt.figure(figsize=(10,8))  # Sets the size of the displayed image
plt.imshow(test_image)
